# %% [markdown]
# Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5 using Python. Interpret the results.

# %%
import scipy.stats as stats

confidence_interval = 0.95
mean = 50 
std = 5
sample_size = 100  # Assuming a sample size of 100
significance = 1-confidence_interval

z_score = stats.norm.ppf(1- significance/2)
margin_of_error = z_score * (std/sample_size ** 0.5)

lower_bound  = mean - margin_of_error
upper_bound  = mean + margin_of_error

print ("lower bound is " ,lower_bound ,"and upper bound is", upper_bound)
# Out:
# lower bound is  49.02001800772997 and upper bound is 50.97998199227003

# %% [markdown]
# Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag
# matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20%
# brown. Use Python to perform the test with a significance level of 0.05.

# %%
from scipy.stats import chisquare
expected_distribution = [0.2* 100, 0.2* 100, 0.2* 100, 0.1* 100, 0.1* 100, 0.2* 100]
observed_distribution = [12,25,20,20,15,8]

chi2_stat, p_value = chisquare(observed_distribution,expected_distribution)

print ("chi-square statistics is :",chi2_stat )
print ("P- value is :",p_value )

significance = 0.05
if p_value <= significance:
    print("Reject the null hypothesis: The distribution of colors in the bag does not match the expected distribution.")
else:
        print("Fail to Reject the null hypothesis: The distribution of colors in the bag match the expected distribution.")
# Out:
# chi-square statistics is : 24.15
# P- value is : 0.00020316575619421605
# Reject the null hypothesis: The distribution of colors in the bag does not match the expected distribution.

# %% [markdown]
# Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following
# data:

# %% [markdown]
# Outcome 1    20    15
#
# Outcome 2    10    25
#
# Outcome 3    15    20

# %%
from scipy.stats import chi2_contingency

# Define the contingency table
observed = [[20, 15],
            [10, 25],
            [15, 20]]

# Perform chi-square test
chi2_stat, p_value, dof, expected = chi2_contingency(observed)

# Print the results
print("Chi-square Statistic:", chi2_stat)
print("p-value:", p_value)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:")
print(expected)
# Out:
# Chi-square Statistic: 5.833333333333334
# p-value: 0.05411376622282158
# Degrees of Freedom: 2
# Expected Frequencies:
# [[15. 20.]
#  [15. 20.]
#  [15. 20.]]

# %% [markdown]
# Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation
# of 12 using Python. Interpret the results.

# %%
mean = 75
std_dev = 12
sample_size = 100  # Assuming a sample size of 100

confidence_level = 0.90
significance = 1 - confidence_level

z_score = stats.norm.ppf(1 - significance/2)
margin_of_error = z_score * (std_dev / (sample_size ** 0.5))

lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

print("90% Confidence Interval: ",(lower_bound, upper_bound))
# Out:
# 90% Confidence Interval:  (73.02617564765823, 76.97382435234177)

# %% [markdown]
# Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the
# area corresponding to a chi-square statistic of 15.

# %%
import matplotlib.pyplot as plot
import numpy as np

dof = 10
 
x = np.linspace(0,30,1000)
pdf = stats.chi2.pdf(x,dof)

plt.plot(x,pdf ,label = "chi-square distribution dof =10")
plt.fill_between(x,pdf ,where = (x>=15) , color = "orange" ,label = "chi-square statistics =15")

plt.xlabel("Chi-square statistic")
plt.ylabel("Probability Density Function")
plt.title("Chi-square distribution")

plt.legend()
plt.show()

# %% [markdown]
# Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520
# preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who
# prefer Coke.

# %%
# Sample size
n = 1000

# Number of people who prefer Coke
x = 520

# Sample proportion
p_hat = x / n

# Standard error
standard_error = np.sqrt(p_hat * (1 - p_hat) / n)

# Z-score for 99% confidence interval
z_score = stats.norm.ppf(0.995)  # 0.995 because we want 0.5% in each tail

# Calculate margin of error
margin_of_error = z_score * standard_error

# Calculate confidence interval
lower_bound = p_hat - margin_of_error
upper_bound = p_hat + margin_of_error

print("99% Confidence Interval for the true proportion of people who prefer Coke: [{:.4f}, {:.4f}]".format(lower_bound, upper_bound))
# Out:
# 99% Confidence Interval for the true proportion of people who prefer Coke: [0.4793, 0.5607]

# %% [markdown]
# Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe
# 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the
# expected frequencies of a fair coin. Use a significance level of 0.05.

# %%
from scipy.stats import chisquare

observed = [45,55]
expected = [50,50]

chi2_stat, p_value = chisquare(observed,expected)

print (chi2_stat ,"is chi-square statistics")
print (p_value ,"is p value")

significance = 0.05
if p_value <= significance:
    print("Reject the null hypothesis: The observed frequencies do not match the expected frequencies of a fair coin.")
else:
    print("Fail to reject the null hypothesis: The observed frequencies match the expected frequencies of a fair coin.")
# Out:
# 1.0 is chi-square statistics
# 0.31731050786291115 is p value
# Fail to reject the null hypothesis: The observed frequencies match the expected frequencies of a fair coin.

# %% [markdown]
# Q9. A study was conducted to determine if there is an association between smoking status (smoker or
# non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below.
# Conduct a chi-square test for independence to determine if there is a significant association between
# smoking status and lung cancer diagnosis.

# %% [raw]
#        Lung Cancer: Yes   Lung Cancer: No
#
# Smoker      60                   140
#
# Non-smoker  30                    170

# %%
from scipy.stats import chi2_contingency

observed= [[ 60 , 140],
           [30, 170]]

chi2_stat,p_value, dof,expected= chi2_contingency(observed)
print("Chi-square Statistic:", chi2_stat)
print("p-value:", p_value)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:")
print(expected)

alpha = 0.05
if alpha <= p_value:
    print("Reject the null hypothesis: There is a significant association between smoking status and lung cancer diagnosis.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between smoking status and lung cancer diagnosis.")
# Out:
# Chi-square Statistic: 12.057347670250895
# p-value: 0.0005158863863703744
# Degrees of Freedom: 1
# Expected Frequencies:
# [[ 45. 155.]
#  [ 45. 155.]]
# Fail to reject the null hypothesis: There is no significant association between smoking status and lung cancer diagnosis.

# %% [markdown]
# Q10. A study was conducted to determine if the proportion of people who prefer milk chocolate, dark
# chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from
# the U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the
# contingency table below. Conduct a chi-square test for independence to determine if there is a significant
# association between chocolate preference and country of origin.
#
# Use a significance level of 0.01.

# %% [raw]
#                 Milk Chocolate   Dark Chocolate   White Chocolate
#
#
# U.S. (n=500)     200                  150            150
# U.K. (n=500)     225                  175            100

# %%
from scipy.stats import chi2_contingency

# Define the contingency table
observed = [[200, 150, 150],   # U.S.: Milk, Dark, White chocolate preference
            [250, 200, 50]]    # U.K.: Milk, Dark, White chocolate preference

# Perform chi-square test for independence
chi2_stat, p_value, dof, expected = chi2_contingency(observed)

# Print the results
print("Chi-square Statistic:", chi2_stat)
print("p-value:", p_value)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:")
print(expected)

alpha = 0.01
if p_value <= alpha:
    print("Reject the null hypothesis: There is a significant association between chocolate preference and country of origin.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between chocolate preference and country of origin.")
# Out:
# Chi-square Statistic: 62.698412698412696
# p-value: 2.4277986774046572e-14
# Degrees of Freedom: 2
# Expected Frequencies:
# [[225. 175. 100.]
#  [225. 175. 100.]]
# Reject the null hypothesis: There is a significant association between chocolate preference and country of origin.

# %% [markdown]
# Q11. A random sample of 30 people was selected from a population with an unknown mean and standard
# deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10.
# Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a
# significance level of 0.05.

# %%
from scipy.stats import t

# Sample mean and standard deviation
sample_mean = 72
sample_std_dev = 10

# Population mean under the null hypothesis
population_mean = 70

# Sample size
n = 30

# Calculate the t-score
 
t_score = (sample_mean - population_mean)/ (sample_std_dev/np.sqrt(n))

# Calculate the critical t-value at alpha=0.05 and degrees of freedom=n-1

critical_t_value = t.ppf(0.025, df= n-1)

# Perform the hypothesis test
alpha = 0.05
if np.abs(t_score) > critical_t_value:
    print("Reject the null hypothesis: The population mean is significantly different from 70.")
else:
    print("Fail to reject the null hypothesis: The population mean is not significantly different from 70.")
# Out:
# Reject the null hypothesis: The population mean is significantly different from 70.
